# %% [markdown]
# <a href="https://colab.research.google.com/github/joshua-manoj/predictive-maintenance-pipeline/blob/main/Data_Clean_txt_to_CSV_py.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

cols = ['unit_nr', 'time_cycles', 'setting_1', 'setting_2', 'setting_3']
cols += [f's{i}' for i in range(1, 22)]

df = pd.read_csv('train_FD001.txt', sep='\s+', header=None, names=cols)
df.to_csv('train_FD001_clean.csv', index=False)

print("File cleaned! Upload 'train_FD001_clean.csv' to BigQuery now.")
# Out:
# <>:11: SyntaxWarning: invalid escape sequence '\s'
# <>:11: SyntaxWarning: invalid escape sequence '\s'
# /tmp/ipython-input-1924894383.py:11: SyntaxWarning: invalid escape sequence '\s'
#   df = pd.read_csv('train_FD001.txt', sep='\s+', header=None, names=cols)
# File cleaned! Upload 'train_FD001_clean.csv' to BigQuery now.
